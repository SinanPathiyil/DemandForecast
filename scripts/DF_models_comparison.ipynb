# %%
# ================= Import Libraries =================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Time series models
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from prophet import Prophet

# Machine learning
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# Deep learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense

# ---------------- Croston Method ----------------
def croston(ts, alpha=0.4):
    ts = np.array(ts)
    demand = np.zeros_like(ts, dtype=float)
    p = np.zeros_like(ts, dtype=float)
    q = np.zeros_like(ts, dtype=float)
    first = np.where(ts != 0)[0][0]
    demand[first] = ts[first]
    q[first] = 1
    p[first] = 1
    for t in range(first+1, len(ts)):
        if ts[t] != 0:
            demand[t] = alpha * ts[t] + (1-alpha) * demand[t-1]
            p[t] = alpha * (t - np.where(ts[:t]!=0)[0][-1]) + (1-alpha) * p[t-1]
            q[t] = 1
        else:
            demand[t] = demand[t-1]
            p[t] = p[t-1]
            q[t] = q[t-1]
    forecast = demand / p
    return forecast

# ---------------- LSTM/GRU Sequence Helper ----------------
def create_sequences(data, time_steps=3):
    X, y_seq = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y_seq.append(data[i+time_steps])
    return np.array(X), np.array(y_seq)

# ---------------- Load Dataset ----------------
df = pd.read_excel("/content/demand_prediction_weekly.xlsx")

# Ensure weekly sort order
df = df.sort_values(['Product_Name', 'Week'])

# Convert 'Week' to a datetime for Prophet and plotting
df['Date'] = pd.to_datetime(df['Week'].astype(str) + '-1', format='%Y-W%W-%w')

# Get all unique products
products = df['Product_Name'].unique()

# ---------------- Loop over Products ----------------
for product in products:
    print(f"\n========== Forecasting for {product} ==========")
    product_df = df[df['Product_Name'] == product].copy()
    product_df = product_df.groupby('Date')['Total_Quantity'].sum().reset_index()
    product_df = product_df.set_index('Date').asfreq('W-MON', fill_value=0)
    y = product_df['Total_Quantity']

    # ---- Train/Test Split ----
    train_size = int(len(y) * 0.8)
    y_train, y_test = y[:train_size], y[train_size:]

    results = []
    preds = {}

    # ---------------- ARIMA ----------------
    try:
        arima_model = ARIMA(y_train, order=(1,1,1)).fit()
        pred_arima = arima_model.forecast(steps=len(y_test))
        results.append(('ARIMA', mean_absolute_error(y_test, pred_arima), np.sqrt(mean_squared_error(y_test, pred_arima))))
        preds['ARIMA'] = pred_arima
    except Exception as e:
        results.append(('ARIMA', None, None))
        print("ARIMA failed:", e)

    # ---------------- SARIMA ----------------
    try:
        sarima_model = SARIMAX(y_train, order=(1,1,1), seasonal_order=(1,1,1,52)).fit(disp=False)
        pred_sarima = sarima_model.forecast(steps=len(y_test))
        results.append(('SARIMA', mean_absolute_error(y_test, pred_sarima), np.sqrt(mean_squared_error(y_test, pred_sarima))))
        preds['SARIMA'] = pred_sarima
    except Exception as e:
        results.append(('SARIMA', None, None))
        print("SARIMA failed:", e)

    # ---------------- Prophet ----------------
    try:
        prophet_df = y_train.reset_index().rename(columns={'Date':'ds','Total_Quantity':'y'})
        prophet_model = Prophet(weekly_seasonality=True, daily_seasonality=False)
        prophet_model.fit(prophet_df)
        future = prophet_model.make_future_dataframe(periods=len(y_test), freq='W')
        forecast = prophet_model.predict(future)
        pred_prophet = forecast['yhat'].iloc[-len(y_test):].values
        results.append(('Prophet', mean_absolute_error(y_test, pred_prophet), np.sqrt(mean_squared_error(y_test, pred_prophet))))
        preds['Prophet'] = pred_prophet
    except Exception as e:
        results.append(('Prophet', None, None))
        print("Prophet failed:", e)

    # ---------------- ETS ----------------
    try:
        ets_model = ExponentialSmoothing(y_train, trend='add', seasonal='add', seasonal_periods=52).fit()
        pred_ets = ets_model.forecast(len(y_test))
        results.append(('ETS', mean_absolute_error(y_test, pred_ets), np.sqrt(mean_squared_error(y_test, pred_ets))))
        preds['ETS'] = pred_ets
    except Exception as e:
        results.append(('ETS', None, None))
        print("ETS failed:", e)

    # ---------------- XGBoost ----------------
    try:
        lags = 3
        X_train = pd.DataFrame({f'lag_{i}': y_train.shift(i) for i in range(1,lags+1)}).dropna()
        y_train_xgb = y_train[lags:]
        X_test = pd.DataFrame({f'lag_{i}': y_test.shift(i) for i in range(1,lags+1)}).dropna()
        y_test_xgb = y_test[lags:]
        xgb_model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100)
        xgb_model.fit(X_train, y_train_xgb)
        pred_xgb = xgb_model.predict(X_test)
        results.append(('XGBoost', mean_absolute_error(y_test_xgb, pred_xgb), np.sqrt(mean_squared_error(y_test_xgb, pred_xgb))))
        preds['XGBoost'] = (pred_xgb, y_test_xgb)
    except Exception as e:
        results.append(('XGBoost', None, None))
        print("XGBoost failed:", e)

    # ---------------- Croston ----------------
    try:
        pred_croston = croston(y_train.tolist())[-len(y_test):]
        results.append(('Croston', mean_absolute_error(y_test, pred_croston), np.sqrt(mean_squared_error(y_test, pred_croston))))
        preds['Croston'] = pred_croston
    except Exception as e:
        results.append(('Croston', None, None))
        print("Croston failed:", e)

    # ---------------- LSTM ----------------
    try:
        scaler = MinMaxScaler()
        y_scaled = scaler.fit_transform(y.values.reshape(-1,1))
        train_scaled = y_scaled[:train_size]
        test_scaled = y_scaled[train_size:]

        X_train_lstm, y_train_lstm = create_sequences(train_scaled, time_steps=3)
        X_test_lstm, y_test_lstm_seq = create_sequences(test_scaled, time_steps=3)

        model = Sequential([
            LSTM(50, activation='relu', input_shape=(X_train_lstm.shape[1], 1)),
            Dense(1)
        ])
        model.compile(optimizer='adam', loss='mse')
        model.fit(X_train_lstm, y_train_lstm, epochs=30, batch_size=1, verbose=0)

        y_pred_lstm_scaled = model.predict(X_test_lstm)
        y_pred_lstm = scaler.inverse_transform(y_pred_lstm_scaled)
        y_test_actual = y[train_size + 3:]
        results.append(('LSTM', mean_absolute_error(y_test_actual, y_pred_lstm), np.sqrt(mean_squared_error(y_test_actual, y_pred_lstm))))
        preds['LSTM'] = y_pred_lstm
    except Exception as e:
        results.append(('LSTM', None, None))
        print("LSTM failed:", e)

    # ---------------- GRU ----------------
    try:
        scaler = MinMaxScaler()
        y_scaled = scaler.fit_transform(y.values.reshape(-1,1))
        train_scaled = y_scaled[:train_size]
        test_scaled = y_scaled[train_size:]

        X_train_gru, y_train_gru = create_sequences(train_scaled, time_steps=3)
        X_test_gru, y_test_gru_seq = create_sequences(test_scaled, time_steps=3)

        model_gru = Sequential([
            GRU(50, activation='relu', input_shape=(X_train_gru.shape[1], 1)),
            Dense(1)
        ])
        model_gru.compile(optimizer='adam', loss='mse')
        model_gru.fit(X_train_gru, y_train_gru, epochs=30, batch_size=1, verbose=0)

        y_pred_gru_scaled = model_gru.predict(X_test_gru)
        y_pred_gru = scaler.inverse_transform(y_pred_gru_scaled)
        y_test_actual = y[train_size + 3:]
        results.append(('GRU', mean_absolute_error(y_test_actual, y_pred_gru), np.sqrt(mean_squared_error(y_test_actual, y_pred_gru))))
        preds['GRU'] = y_pred_gru
    except Exception as e:
        results.append(('GRU', None, None))
        print("GRU failed:", e)

    # ---------------- Display Results ----------------
    print("\nModel Comparison:")
    for name, mae, rmse in results:
        print(f"{name:10s} | MAE: {mae if mae is not None else 'NA'} | RMSE: {rmse if rmse is not None else 'NA'}")

    # ---------------- Forecast Plot ----------------
    plt.figure(figsize=(12,6))
    plt.plot(y_test.index, y_test, label='Actual', marker='o')
    for name, pred in preds.items():
        if name == 'XGBoost':
            plt.plot(pred[1].index, pred[0], label=name)
        else:
            plt.plot(y_test.index[-len(pred):], pred, label=name)
    plt.legend()
    plt.title(f"Forecast Comparison for {product}")
    plt.show()

    # ---------------- Bar Chart (MAE & RMSE) ----------------
    model_names = [r[0] for r in results]
    maes = [r[1] if r[1] is not None else 0 for r in results]
    rmses = [r[2] if r[2] is not None else 0 for r in results]

    x = np.arange(len(model_names))
    width = 0.35
    plt.figure(figsize=(10,5))
    plt.bar(x - width/2, maes, width, label='MAE')
    plt.bar(x + width/2, rmses, width, label='RMSE')
    plt.xticks(x, model_names, rotation=45)
    plt.ylabel("Error")
    plt.title(f"Error Metrics for {product}")
    plt.legend()
    plt.show()
# Out:
# ========== Forecasting for CLINMISKIN GEL* ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/7tty02z4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/y9f84ary.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27798', 'data', 'file=/tmp/tmp1ehsw98c/7tty02z4.json', 'init=/tmp/tmp1ehsw98c/y9f84ary.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modelxu9j39r1/prophet_model-20251026052158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:21:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:21:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
#
# Model Comparison:
# ARIMA      | MAE: 0.9904067996644182 | RMSE: 1.120547079272049
# SARIMA     | MAE: 1.772566364581392 | RMSE: 2.527100132631381
# Prophet    | MAE: 1.8498447103873328 | RMSE: 2.1293409527850207
# ETS        | MAE: 1.4963689048435727 | RMSE: 1.846620323056806
# XGBoost    | MAE: 1.215749740600586 | RMSE: 1.50201939708208
# Croston    | MAE: 1.3168953934273544 | RMSE: 1.5982147650191818
# LSTM       | MAE: 0.8332930207252502 | RMSE: 0.9335679246211489
# GRU        | MAE: 0.9650517106056213 | RMSE: 1.104857258790309
# ========== Forecasting for DESWIN  TAB ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/4vnbzaje.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/pldw17nj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16822', 'data', 'file=/tmp/tmp1ehsw98c/4vnbzaje.json', 'init=/tmp/tmp1ehsw98c/pldw17nj.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modelbkajybms/prophet_model-20251026052300.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:23:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:23:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f4e6e94b920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f4e6e94b920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#
# Model Comparison:
# ARIMA      | MAE: 19.231113686746276 | RMSE: 24.854156130757204
# SARIMA     | MAE: 25.858598254258812 | RMSE: 32.5004765710803
# Prophet    | MAE: 27.605262202871263 | RMSE: 36.138200143754005
# ETS        | MAE: 25.75242797912255 | RMSE: 32.80526047512688
# XGBoost    | MAE: 14.869722366333008 | RMSE: 23.82486145683748
# Croston    | MAE: 18.982545543166033 | RMSE: 24.486664311902476
# LSTM       | MAE: 15.787585258483887 | RMSE: 22.53766785113244
# GRU        | MAE: 15.320195198059082 | RMSE: 22.356997274867606
# ========== Forecasting for K GLIM-M 1MG ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/zc_sfw4u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/wl8g1vm9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57355', 'data', 'file=/tmp/tmp1ehsw98c/zc_sfw4u.json', 'init=/tmp/tmp1ehsw98c/wl8g1vm9.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modelzo9l1zaa/prophet_model-20251026052358.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:23:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:23:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#
# Model Comparison:
# ARIMA      | MAE: 18.196899927372755 | RMSE: 22.192597307179252
# SARIMA     | MAE: 16.571641335879654 | RMSE: 24.868944257183824
# Prophet    | MAE: 23.713316359504972 | RMSE: 25.867989670281208
# ETS        | MAE: 15.362132599655727 | RMSE: 22.978014049853545
# XGBoost    | MAE: 19.92876625061035 | RMSE: 27.017457192786715
# Croston    | MAE: 18.912646508740796 | RMSE: 21.865044148076855
# LSTM       | MAE: 18.80881690979004 | RMSE: 21.704683647460243
# GRU        | MAE: 18.438268661499023 | RMSE: 21.445673949595143
# ========== Forecasting for MEFORNIX P ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/9jdv2_mb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/pzpo9o6a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14588', 'data', 'file=/tmp/tmp1ehsw98c/9jdv2_mb.json', 'init=/tmp/tmp1ehsw98c/pzpo9o6a.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_model95rni5s_/prophet_model-20251026052456.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /tmp/ipython-input-126431388.py:40: RuntimeWarning: invalid value encountered in divide
#   forecast = demand / p
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 226ms/step
#
# Model Comparison:
# ARIMA      | MAE: 6.888418005989403 | RMSE: 8.471937075324217
# SARIMA     | MAE: 7.402133439198688 | RMSE: 9.100121229893512
# Prophet    | MAE: 10.745955626552016 | RMSE: 12.37148245065702
# ETS        | MAE: 7.405420140013912 | RMSE: 9.005555494902147
# XGBoost    | MAE: 8.810370445251465 | RMSE: 12.652242445179493
# Croston    | MAE: 9.042058637831408 | RMSE: 10.326911200309237
# LSTM       | MAE: 5.92794942855835 | RMSE: 8.009383896887128
# GRU        | MAE: 5.999266624450684 | RMSE: 8.26283375676254
# ========== Forecasting for MONTEMAC FX TAB ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/j9naa1jj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/44hs_7fs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33874', 'data', 'file=/tmp/tmp1ehsw98c/j9naa1jj.json', 'init=/tmp/tmp1ehsw98c/44hs_7fs.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modeld9pehi3t/prophet_model-20251026052534.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:25:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:25:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /tmp/ipython-input-126431388.py:40: RuntimeWarning: invalid value encountered in divide
#   forecast = demand / p
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
#
# Model Comparison:
# ARIMA      | MAE: 16.346301803695678 | RMSE: 22.758170731528892
# SARIMA     | MAE: 45.08952834002324 | RMSE: 58.31425252643188
# Prophet    | MAE: 59.90333736575334 | RMSE: 64.67687821635012
# ETS        | MAE: 31.715886685979406 | RMSE: 37.63472960564268
# XGBoost    | MAE: 19.919891357421875 | RMSE: 28.137236921249038
# Croston    | MAE: 34.36833742876503 | RMSE: 39.060649561729164
# LSTM       | MAE: 17.92266082763672 | RMSE: 24.40365403127419
# GRU        | MAE: 17.4498348236084 | RMSE: 24.53921049183327
# ========== Forecasting for MOXCLAV 625 ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/holtwinters/model.py:903: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/holtwinters/model.py:1380: RuntimeWarning: divide by zero encountered in log
#   aic = self.nobs * np.log(sse / self.nobs) + k * 2
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/holtwinters/model.py:1387: RuntimeWarning: divide by zero encountered in log
#   bic = self.nobs * np.log(sse / self.nobs) + k * np.log(self.nobs)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/holtwinters/model.py:1380: RuntimeWarning: divide by zero encountered in log
#   aic = self.nobs * np.log(sse / self.nobs) + k * 2
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/holtwinters/model.py:1387: RuntimeWarning: divide by zero encountered in log
#   bic = self.nobs * np.log(sse / self.nobs) + k * np.log(self.nobs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Croston failed: index 0 is out of bounds for axis 0 with size 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
#
# Model Comparison:
# ARIMA      | MAE: 20.095238095238095 | RMSE: 31.8111989864007
# SARIMA     | MAE: 20.095238095238095 | RMSE: 31.8111989864007
# Prophet    | MAE: 20.095238095238095 | RMSE: 31.8111989864007
# ETS        | MAE: 20.095238095238095 | RMSE: 31.8111989864007
# XGBoost    | MAE: 21.64102554321289 | RMSE: 33.01204207368881
# Croston    | MAE: NA | RMSE: NA
# LSTM       | MAE: 21.9255313873291 | RMSE: 33.333788855936966
# GRU        | MAE: 22.346193313598633 | RMSE: 33.80352743127372
# ========== Forecasting for PANTOP - 40  TAB ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/gjxfomwu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/xa9rhzf5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=97722', 'data', 'file=/tmp/tmp1ehsw98c/gjxfomwu.json', 'init=/tmp/tmp1ehsw98c/xa9rhzf5.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modelh8hjpnrp/prophet_model-20251026052714.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:27:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:27:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /tmp/ipython-input-126431388.py:40: RuntimeWarning: invalid value encountered in divide
#   forecast = demand / p
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
#
# Model Comparison:
# ARIMA      | MAE: 4.202770361264608 | RMSE: 6.43241178272247
# SARIMA     | MAE: 5.552488905236701 | RMSE: 7.983641849216867
# Prophet    | MAE: 9.90908178981779 | RMSE: 12.11446693810007
# ETS        | MAE: 6.136595151522391 | RMSE: 8.269467631447206
# XGBoost    | MAE: 6.058516502380371 | RMSE: 8.22533869176451
# Croston    | MAE: 4.1097845197106855 | RMSE: 6.314442084008971
# LSTM       | MAE: 4.624455451965332 | RMSE: 6.653800979467693
# GRU        | MAE: 4.934204578399658 | RMSE: 6.838849547157921
# ========== Forecasting for TELMIGET  40  TAB ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/4jkerlhy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/y3oblk3d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20070', 'data', 'file=/tmp/tmp1ehsw98c/4jkerlhy.json', 'init=/tmp/tmp1ehsw98c/y3oblk3d.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_model582n66q1/prophet_model-20251026052808.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
#
# Model Comparison:
# ARIMA      | MAE: 6.137875573278707 | RMSE: 7.376848093959258
# SARIMA     | MAE: 6.873390774389711 | RMSE: 8.772899167144065
# Prophet    | MAE: 9.583438572734462 | RMSE: 10.443489412264421
# ETS        | MAE: 6.471692260186372 | RMSE: 8.665093062728426
# XGBoost    | MAE: 5.082363605499268 | RMSE: 7.722339120005997
# Croston    | MAE: 5.701732725889353 | RMSE: 7.652320760096164
# LSTM       | MAE: 5.2579426765441895 | RMSE: 8.033474506493711
# GRU        | MAE: 5.376131057739258 | RMSE: 7.841325483963727
# ========== Forecasting for TIBRIO ==========
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/0nrz0c6k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp1ehsw98c/hac5a3g9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.12/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=53393', 'data', 'file=/tmp/tmp1ehsw98c/0nrz0c6k.json', 'init=/tmp/tmp1ehsw98c/hac5a3g9.json', 'output', 'file=/tmp/tmp1ehsw98c/prophet_modelz5womnmw/prophet_model-20251026052853.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:28:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:28:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
#
# Model Comparison:
# ARIMA      | MAE: 17.04004539926363 | RMSE: 19.895691274927994
# SARIMA     | MAE: 18.613193734434077 | RMSE: 22.474547482675135
# Prophet    | MAE: 16.656004770940232 | RMSE: 20.07984461637011
# ETS        | MAE: 20.484284157230142 | RMSE: 25.36685921001977
# XGBoost    | MAE: 12.140438079833984 | RMSE: 15.721066010417559
# Croston    | MAE: 17.116070921596414 | RMSE: 20.3097065549404
# LSTM       | MAE: 12.96947193145752 | RMSE: 16.811509794550446
# GRU        | MAE: 12.601472854614258 | RMSE: 15.83834379457882
